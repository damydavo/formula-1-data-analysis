# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
results = pd.read_csv('results.csv')
races = pd.read_csv('races.csv')
drivers = pd.read_csv('drivers.csv')
constructors = pd.read_csv('constructors.csv')

# %%
df = pd.merge(results, races[['raceId', 'year', 'name', 'round']], on = 'raceId', how = 'left')
df = pd.merge(df, drivers[['driverId', 'driverRef', 'nationality']], on = 'driverId', how = 'left')
df = pd.merge(df, constructors[['constructorId', 'name', 'nationality']], on = 'constructorId', how = 'left')

# %%
df.shape
# Out:
# (25660, 25)

# %%
df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25655     25661    1086       825            210     20    13       16
# 25656     25662    1086       848              3     23    17       17
# 25657     25663    1086       849              3      6    19       18
# 25658     25664    1086       852            213     22    16       19
# 25659     25665    1086       822             51     77     8       20
#
#       positionText  positionOrder  points  ...  fastestLapTime  \
# 0                1              1    10.0  ...        1:27.452
# 1                2              2     8.0  ...        1:27.739
# 2                3              3     6.0  ...        1:28.090
# 3                4              4     5.0  ...        1:28.603
# 4                5              5     4.0  ...        1:27.418
# ...            ...            ...     ...  ...             ...
# 25655           16             16     0.0  ...        1:23.511
# 25656           17             17     0.0  ...        1:23.047
# 25657           18             18     0.0  ...        1:22.478
# 25658           19             19     0.0  ...        1:23.538
# 25659           20             20     0.0  ...        1:24.002
#
#       fastestLapSpeed statusId  year                 name_x round  \
# 0             218.300        1  2008  Australian Grand Prix     1
# 1             217.586        1  2008  Australian Grand Prix     1
# 2             216.719        1  2008  Australian Grand Prix     1
# 3             215.464        1  2008  Australian Grand Prix     1
# 4             218.385        1  2008  Australian Grand Prix     1
# ...               ...      ...   ...                    ...   ...
# 25655         188.856       11  2022   Hungarian Grand Prix    13
# 25656         189.911       11  2022   Hungarian Grand Prix    13
# 25657         191.221       11  2022   Hungarian Grand Prix    13
# 25658         188.795       12  2022   Hungarian Grand Prix    13
# 25659         187.752      131  2022   Hungarian Grand Prix    13
#
#              driverRef  nationality_x        name_y nationality_y
# 0             hamilton        British       McLaren       British
# 1             heidfeld         German    BMW Sauber        German
# 2              rosberg         German      Williams       British
# 3               alonso        Spanish       Renault        French
# 4           kovalainen        Finnish       McLaren       British
# ...                ...            ...           ...           ...
# 25655  kevin_magnussen         Danish  Haas F1 Team      American
# 25656            albon           Thai      Williams       British
# 25657           latifi       Canadian      Williams       British
# 25658          tsunoda       Japanese    AlphaTauri       Italian
# 25659           bottas        Finnish    Alfa Romeo         Swiss
#
# [25660 rows x 25 columns]

# %%
# drop columns

df.drop(['number', 'position', 'positionText', 'laps', 'fastestLap', 'statusId', 'resultId', 'raceId', 'driverId', 'constructorId'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    grid  positionOrder  points         time milliseconds rank fastestLapTime  \
# 0     1              1    10.0  1:34:50.616      5690616    2       1:27.452
# 1     5              2     8.0       +5.478      5696094    3       1:27.739
# 2     7              3     6.0       +8.163      5698779    5       1:28.090
# 3    11              4     5.0      +17.181      5707797    7       1:28.603
# 4     3              5     4.0      +18.014      5708630    1       1:27.418
#
#   fastestLapSpeed  year                 name_x  round   driverRef  \
# 0         218.300  2008  Australian Grand Prix      1    hamilton
# 1         217.586  2008  Australian Grand Prix      1    heidfeld
# 2         216.719  2008  Australian Grand Prix      1     rosberg
# 3         215.464  2008  Australian Grand Prix      1      alonso
# 4         218.385  2008  Australian Grand Prix      1  kovalainen
#
#   nationality_x      name_y nationality_y
# 0       British     McLaren       British
# 1        German  BMW Sauber        German
# 2        German    Williams       British
# 3       Spanish     Renault        French
# 4       Finnish     McLaren       British

# %%
df.shape
# Out:
# (25660, 15)

# %%
df.rename(columns={'rank': 'fastestLapRank', 'name_x': 'gpName', 'nationality_x': 'driverNationality', 'name_y': 'constructorName', 'nationality_y' : 'constructorNationality', 'driverRef': 'driver'}, inplace=True)

# %%
df.head()
# Out:
#    grid  positionOrder  points         time milliseconds fastestLapRank  \
# 0     1              1    10.0  1:34:50.616      5690616              2
# 1     5              2     8.0       +5.478      5696094              3
# 2     7              3     6.0       +8.163      5698779              5
# 3    11              4     5.0      +17.181      5707797              7
# 4     3              5     4.0      +18.014      5708630              1
#
#   fastestLapTime fastestLapSpeed  year                 gpName  round  \
# 0       1:27.452         218.300  2008  Australian Grand Prix      1
# 1       1:27.739         217.586  2008  Australian Grand Prix      1
# 2       1:28.090         216.719  2008  Australian Grand Prix      1
# 3       1:28.603         215.464  2008  Australian Grand Prix      1
# 4       1:27.418         218.385  2008  Australian Grand Prix      1
#
#        driver driverNationality constructorName constructorNationality
# 0    hamilton           British         McLaren                British
# 1    heidfeld            German      BMW Sauber                 German
# 2     rosberg            German        Williams                British
# 3      alonso           Spanish         Renault                 French
# 4  kovalainen           Finnish         McLaren                British

# %%
# rearrange column
df.columns
# Out:
# Index(['grid', 'positionOrder', 'points', 'time', 'milliseconds',
#        'fastestLapRank', 'fastestLapTime', 'fastestLapSpeed', 'year', 'gpName',
#        'round', 'driver', 'driverNationality', 'constructorName',
#        'constructorNationality'],
#       dtype='object')

# %%
df=df[['year', 'gpName', 'round', 'driver', 'constructorName', 'grid', 'positionOrder', 'points', 'time', 'milliseconds', 'fastestLapRank', 
      'fastestLapTime', 'fastestLapSpeed', 'driverNationality', 'constructorNationality']]

# %%
df.head()
# Out:
#    year                 gpName  round      driver constructorName  grid  \
# 0  2008  Australian Grand Prix      1    hamilton         McLaren     1
# 1  2008  Australian Grand Prix      1    heidfeld      BMW Sauber     5
# 2  2008  Australian Grand Prix      1     rosberg        Williams     7
# 3  2008  Australian Grand Prix      1      alonso         Renault    11
# 4  2008  Australian Grand Prix      1  kovalainen         McLaren     3
#
#    positionOrder  points         time milliseconds fastestLapRank  \
# 0              1    10.0  1:34:50.616      5690616              2
# 1              2     8.0       +5.478      5696094              3
# 2              3     6.0       +8.163      5698779              5
# 3              4     5.0      +17.181      5707797              7
# 4              5     4.0      +18.014      5708630              1
#
#   fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 0       1:27.452         218.300           British                British
# 1       1:27.739         217.586            German                 German
# 2       1:28.090         216.719            German                British
# 3       1:28.603         215.464           Spanish                 French
# 4       1:27.418         218.385           Finnish                British

# %%
df
# Out:
#        year                 gpName  round           driver constructorName  \
# 0      2008  Australian Grand Prix      1         hamilton         McLaren
# 1      2008  Australian Grand Prix      1         heidfeld      BMW Sauber
# 2      2008  Australian Grand Prix      1          rosberg        Williams
# 3      2008  Australian Grand Prix      1           alonso         Renault
# 4      2008  Australian Grand Prix      1       kovalainen         McLaren
# ...     ...                    ...    ...              ...             ...
# 25655  2022   Hungarian Grand Prix     13  kevin_magnussen    Haas F1 Team
# 25656  2022   Hungarian Grand Prix     13            albon        Williams
# 25657  2022   Hungarian Grand Prix     13           latifi        Williams
# 25658  2022   Hungarian Grand Prix     13          tsunoda      AlphaTauri
# 25659  2022   Hungarian Grand Prix     13           bottas      Alfa Romeo
#
#        grid  positionOrder  points         time milliseconds fastestLapRank  \
# 0         1              1    10.0  1:34:50.616      5690616              2
# 1         5              2     8.0       +5.478      5696094              3
# 2         7              3     6.0       +8.163      5698779              5
# 3        11              4     5.0      +17.181      5707797              7
# 4         3              5     4.0      +18.014      5708630              1
# ...     ...            ...     ...          ...          ...            ...
# 25655    13             16     0.0           \N           \N             15
# 25656    17             17     0.0           \N           \N             12
# 25657    19             18     0.0           \N           \N              8
# 25658    16             19     0.0           \N           \N             16
# 25659     8             20     0.0           \N           \N             19
#
#       fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 0           1:27.452         218.300           British                British
# 1           1:27.739         217.586            German                 German
# 2           1:28.090         216.719            German                British
# 3           1:28.603         215.464           Spanish                 French
# 4           1:27.418         218.385           Finnish                British
# ...              ...             ...               ...                    ...
# 25655       1:23.511         188.856            Danish               American
# 25656       1:23.047         189.911              Thai                British
# 25657       1:22.478         191.221          Canadian                British
# 25658       1:23.538         188.795          Japanese                Italian
# 25659       1:24.002         187.752           Finnish                  Swiss
#
# [25660 rows x 15 columns]

# %%
df.describe()
# Out:
#                year         round          grid  positionOrder        points
# count  25660.000000  25660.000000  25660.000000   25660.000000  25660.000000
# mean    1990.029072      8.318550     11.187256      12.892673      1.854523
# std       19.229104      4.904752      7.251983       7.721729      4.131527
# min     1950.000000      1.000000      0.000000       1.000000      0.000000
# 25%     1976.000000      4.000000      5.000000       6.000000      0.000000
# 50%     1990.000000      8.000000     11.000000      12.000000      0.000000
# 75%     2007.000000     12.000000     17.000000      18.000000      2.000000
# max     2022.000000     22.000000     34.000000      39.000000     50.000000

# %%
df = df[df['year']!=2019]

# %%
df.head()
# Out:
#    year                 gpName  round      driver constructorName  grid  \
# 0  2008  Australian Grand Prix      1    hamilton         McLaren     1
# 1  2008  Australian Grand Prix      1    heidfeld      BMW Sauber     5
# 2  2008  Australian Grand Prix      1     rosberg        Williams     7
# 3  2008  Australian Grand Prix      1      alonso         Renault    11
# 4  2008  Australian Grand Prix      1  kovalainen         McLaren     3
#
#    positionOrder  points         time milliseconds fastestLapRank  \
# 0              1    10.0  1:34:50.616      5690616              2
# 1              2     8.0       +5.478      5696094              3
# 2              3     6.0       +8.163      5698779              5
# 3              4     5.0      +17.181      5707797              7
# 4              5     4.0      +18.014      5708630              1
#
#   fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 0       1:27.452         218.300           British                British
# 1       1:27.739         217.586            German                 German
# 2       1:28.090         216.719            German                British
# 3       1:28.603         215.464           Spanish                 French
# 4       1:27.418         218.385           Finnish                British

# %%
# sort values
df = df.sort_values(by=['year', 'round', 'positionOrder'], ascending = [False, True, True])

# %%
df.head()
# Out:
#        year              gpName  round           driver constructorName  grid  \
# 25400  2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 25401  2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 25402  2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 25403  2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 25404  2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
#
#        positionOrder  points         time milliseconds fastestLapRank  \
# 25400              1    26.0  1:37:33.584      5853584              1
# 25401              2    18.0       +5.598      5859182              3
# 25402              3    15.0       +9.675      5863259              5
# 25403              4    12.0      +11.211      5864795              6
# 25404              5    10.0      +14.754      5868338              8
#
#       fastestLapTime fastestLapSpeed driverNationality constructorNationality
# 25400       1:34.570         206.018        Monegasque                Italian
# 25401       1:35.740         203.501           Spanish                Italian
# 25402       1:36.228         202.469           British                 German
# 25403       1:36.302         202.313           British                 German
# 25404       1:36.623         201.641            Danish               American

# %%
# replace /N values in the time column with NAN
df.time.replace('\\N', np.nan, inplace=True)
df.milliseconds.replace('\\N', np.nan, inplace=True)
df.fastestLapRank.replace('\\N', np.nan, inplace=True)
df.fastestLapTime.replace('\\N', np.nan, inplace=True)
df.fastestLapSpeed.replace('\\N', np.nan, inplace=True)

# %%
# change datatypes
df.fastestLapSpeed = df.fastestLapSpeed.astype(float)
df.fastestLapRank = df.fastestLapRank.astype(float)
df.milliseconds = df.milliseconds.astype(float)

# %%
# reset index
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (25240, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25240 entries, 0 to 25239
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    25240 non-null  int64
#  1   gpName                  25240 non-null  object
#  2   round                   25240 non-null  int64
#  3   driver                  25240 non-null  object
#  4   constructorName         25240 non-null  object
#  5   grid                    25240 non-null  int64
#  6   positionOrder           25240 non-null  int64
#  7   points                  25240 non-null  float64
#  8   time                    6768 non-null   object
#  9   milliseconds            6767 non-null   float64
#  10  fastestLapRank          6991 non-null   float64
#  11  fastestLapTime          6790 non-null   object
#  12  fastestLapSpeed         6790 non-null   float64
#  13  driverNationality       25240 non-null  object
#  14  constructorNationality  25240 non-null  object
# dtypes: float64(4), int64(4), object(7)
# memory usage: 2.9+ MB

# %%
df.head(10)
# Out:
#    year              gpName  round           driver constructorName  grid  \
# 0  2022  Bahrain Grand Prix      1          leclerc         Ferrari     1
# 1  2022  Bahrain Grand Prix      1            sainz         Ferrari     3
# 2  2022  Bahrain Grand Prix      1         hamilton        Mercedes     5
# 3  2022  Bahrain Grand Prix      1          russell        Mercedes     9
# 4  2022  Bahrain Grand Prix      1  kevin_magnussen    Haas F1 Team     7
# 5  2022  Bahrain Grand Prix      1           bottas      Alfa Romeo     6
# 6  2022  Bahrain Grand Prix      1             ocon  Alpine F1 Team    11
# 7  2022  Bahrain Grand Prix      1          tsunoda      AlphaTauri    16
# 8  2022  Bahrain Grand Prix      1           alonso  Alpine F1 Team     8
# 9  2022  Bahrain Grand Prix      1             zhou      Alfa Romeo    15
#
#    positionOrder  points         time  milliseconds  fastestLapRank  \
# 0              1    26.0  1:37:33.584     5853584.0             1.0
# 1              2    18.0       +5.598     5859182.0             3.0
# 2              3    15.0       +9.675     5863259.0             5.0
# 3              4    12.0      +11.211     5864795.0             6.0
# 4              5    10.0      +14.754     5868338.0             8.0
# 5              6     8.0      +16.119     5869703.0             7.0
# 6              7     6.0      +19.423     5873007.0            14.0
# 7              8     4.0      +20.386     5873970.0            13.0
# 8              9     2.0      +22.390     5875974.0            10.0
# 9             10     1.0      +23.064     5876648.0             9.0
#
#   fastestLapTime  fastestLapSpeed driverNationality constructorNationality
# 0       1:34.570          206.018        Monegasque                Italian
# 1       1:35.740          203.501           Spanish                Italian
# 2       1:36.228          202.469           British                 German
# 3       1:36.302          202.313           British                 German
# 4       1:36.623          201.641            Danish               American
# 5       1:36.599          201.691           Finnish                  Swiss
# 6       1:37.110          200.630            French                 French
# 7       1:37.104          200.642          Japanese                Italian
# 8       1:36.733          201.412           Spanish                 French
# 9       1:36.685          201.512           Chinese                  Swiss

# %%
sns.set_palette('Set3')
plt.rcParams['figure.figsize']=10,6

# %%
# GP winners
driver_winner =df.loc[df['positionOrder']==1].groupby('driver')['positionOrder'].count().sort_values(ascending=False).to_frame().reset_index()

# Barplot

sns.barplot(data=driver_winner, y='driver', x='positionOrder', color='green', alpha=0.8)
plt.title('Most Gp winners in F1')
plt.ylabel('Driver Name')
plt.xlabel('Number of GP wins')
plt.yticks([])
# Out:
# ([], [])

# %%
# create a new dataFrame of top ten GP winners

top10Drivers = driver_winner.head(10)

print(top10Drivers)
# Out:
#                driver  positionOrder
# 0            hamilton             92
# 1  michael_schumacher             91
# 2              vettel             52
# 3               prost             51
# 4               senna             41
# 5              alonso             32
# 6             mansell             31
# 7             stewart             27
# 8               clark             25
# 9               lauda             25

# %%
# top 10 drivers barplot

sns.barplot(data=top10Drivers, y='driver', x='positionOrder', color='magenta', alpha=0.8, linewidth=.8, edgecolor='black')
plt.title('Most winners in the F1')
plt.ylabel('Driver Name')
plt.xlabel('Numbers of GP wins');

# %%
# GP constructor winners

# GP winners
constructor_winner =df.loc[df['positionOrder']==1].groupby('constructorName')['positionOrder'].count().sort_values(ascending=False).to_frame().reset_index()

# Barplot

sns.barplot(data=constructor_winner, y='constructorName', x='positionOrder', color='pink', alpha=0.8)
plt.title('Most Gp wins for constructors')
plt.ylabel('Constructors Name')
plt.xlabel('Number of GP wins')
plt.yticks([])
# Out:
# ([], [])

# %%
# create a new dataFrame of top ten constructor winners

top10Constructors = constructor_winner.head(10)

print(top10Constructors)
# Out:
#   constructorName  positionOrder
# 0         Ferrari            240
# 1         McLaren            179
# 2        Williams            114
# 3        Mercedes            109
# 4        Red Bull             81
# 5      Team Lotus             45
# 6         Renault             35
# 7        Benetton             27
# 8         Brabham             23
# 9         Tyrrell             23

# %%
# top 10 constructors barplot

sns.barplot(data=top10Constructors, y='constructorName', x='positionOrder', color='blue', alpha=0.8, linewidth=.8, edgecolor='black')
plt.title('Most constructors winners in the F1')
plt.ylabel('Constructor Name')
plt.xlabel('Numbers of GP wins');
